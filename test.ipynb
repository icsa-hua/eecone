# %%
import sqlite3
import io
from PIL import Image

db3_file = 'D:/Users/k_chi/VscodeProjects/rosbag2_burning_car_1/rosbag2_burning_car_1_0.db3'

# Connect to the SQLite database
conn = sqlite3.connect(db3_file)
cursor = conn.cursor()

# Retrieve the image BLOB (assuming it's in a table named 'images' with columns 'id' and 'image_data')
cursor.execute("SELECT data FROM messages WHERE id = ?", (1,))  # Replace 1 with your actual image ID
image_blob = cursor.fetchone()[0]

# Convert BLOB to an image
image = Image.open(io.BytesIO(image_blob))

# Show the image
image.show()

# Close the database connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[23], line 16
#      13 image_blob = cursor.fetchone()[0]
#      15 # Convert BLOB to an image
# ---> 16 image = Image.open(io.BytesIO(image_blob))
#      18 # Show the image
#      19 image.show()
#
# File d:\Users\k_chi\VscodeProjects\eecone\venv\lib\site-packages\PIL\Image.py:3498, in open(fp, mode, formats)
#    3496     warnings.warn(message)
#    3497 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3498 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x000001AC786EB950>
